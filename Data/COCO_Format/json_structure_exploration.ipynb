# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir("/content/drive/MyDrive/Thesis_Organized/Data/COCO_Format")

# %%
import json

# Replace 'your_file_path.json' with the path to your actual JSON file
file_path = 'coco_test_data.json'

with open(file_path, 'r') as file:
    data = json.load(file)

data.keys()
# Out:
# dict_keys(['images', 'annotations', 'categories'])

# %%
data["images"][:5]
# Out:
# [{'height': 517, 'width': 658, 'id': 1, 'file_name': 'L1Ap5_1-1-18.png'},
#  {'height': 517, 'width': 658, 'id': 2, 'file_name': 'L1Ap5_10-1-10.png'},
#  {'height': 517, 'width': 658, 'id': 3, 'file_name': 'L1Ap5_10-1-297.png'},
#  {'height': 517, 'width': 658, 'id': 4, 'file_name': 'L1Ap5_10-1-73.png'},
#  {'height': 517, 'width': 658, 'id': 5, 'file_name': 'L1Ap5_11-1-143.png'}]

# %%
print(data["annotations"][0].keys())
# Out:
# dict_keys(['iscrowd', 'image_id', 'bbox', 'segmentation', 'category_id', 'id', 'area'])

# %%
data["categories"]
# Out:
# [{'id': 0, 'name': 'Track', 'supercategory': 'Track'}]
